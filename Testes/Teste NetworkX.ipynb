# %%
import io
from itertools import count
import pymysql
import getpass
import pandas as pd

import networkx as nx
from networkx import Graph as NXGraph
from networkx.drawing.nx_agraph import graphviz_layout

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import collections

from IPython.display import display, Image

# %%
p = getpass.getpass()
# Out:
# ········

# %% [markdown]
# Acho que vale a pena deixar o modelo do banco para termos as conexões em mente

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Quantidade de aeronaves por Companhia

# %%
conn = pymysql.connect(host = 'localhost',
                       user = 'root', 
                       passwd = p, 
                       database = 'usa_flights') # só muda aqui para flights / usa_flights

cur = conn.cursor()

# %%
query = '''
SELECT Companies.name AS Company,
       Count(Companys_id) AS Aircrafts
FROM Aircrafts
INNER JOIN Companies ON Companies.id_company = Aircrafts.Companys_id
GROUP BY Companys_id
ORDER BY Aircrafts DESC;
'''

pd.read_sql_query(query, conn)
# Out:
#                                            Company  Aircrafts
# 0                              DELTA AIR LINES INC        882
# 1                              UNITED AIRLINES INC        856
# 2                            AMERICAN AIRLINES INC        834
# 3                      WELLS FARGO BANK NA TRUSTEE        802
# 4                           SOUTHWEST AIRLINES INC        607
# 5                            SKY WEST AIRLINES INC        442
# 6                      WILMINGTON TRUST CO TRUSTEE        230
# 7                             BANK OF UTAH TRUSTEE        206
# 8                      JETBLUE AIRWAYS CORPORATION        199
# 9                              ALASKA AIRLINES INC        164
# 10                            REPUBLIC AIRWAYS INC        157
# 11                             SPIRIT AIRLINES INC         98
# 12                               MESA AIRLINES INC         85
# 13                             UMB BANK NA TRUSTEE         79
# 14                    SUNRISE ASSET MANAGEMENT LLC         73
# 15            US BANK NATIONAL ASSOCIATION TRUSTEE         52
# 16                           HAWAIIAN AIRLINES INC         41
# 17                             AFS INVESTMENTS LLC         19
# 18                      BCC EQUIPMENT LEASING CORP         14
# 19                               ALLEGIANT AIR LLC         14
# 20                   CARGO AIRCRAFT MANAGEMENT INC          8
# 21                                ALC LLC - CAMDEN          5
# 22                                      JETRAN LLC          4
# 23                        TEXAS AVIATION GROUP LLC          4
# 24        WELLS FARGO DELAWARE TRUST CO NA TRUSTEE          3
# 25                                 AWAS TRUST - NY          3
# 26                    AIRCRAFT MSN STATUTORY TRUST          3
# 27                                AEROCENTURY CORP          3
# 28                                FALCON MSN TRUST          3
# 29                                       NVA TRUST          2
# ..                                             ...        ...
# 63  OKLAHOMA DEPARTMENT OF CAREER & TECH EDUCATION          1
# 64                               PARKER JAMES E JR          1
# 65                         PELLEGRINI AVIATION LLC          1
# 66                                  POTTER CRAIG S          1
# 67                AERIAL PHOTOGRAPHY SOLUTIONS LLC          1
# 68                                        PUNB LLC          1
# 69                      REABE SPRAYING SERVICE INC          1
# 70                                   ENVOY AIR INC          1
# 71                            REPBULIC AIRLINE INC          1
# 72                                    EDDY PETER J          1
# 73                        ROTH AERIAL SPRAYING INC          1
# 74            SASOF III 3445 OWNER STATUTORY TRUST          1
# 75                                  SERVICETEC LLC          1
# 76                          SEUBERT ENTERPRISE INC          1
# 77                                 EARLY DERRICK A          1
# 78                              EADS NORTH AMERICA          1
# 79                                 SPIREDELL TRUST          1
# 80                      AERO CAPITAL SOLUTIONS INC          1
# 81                                JBA HOLDINGS LLC          1
# 82              SWIFT MARKETING AND PROMOTIONS LLC          1
# 83                             DUGGAN HOLDINGS LLC          1
# 84                  TVPX AIRCRAFT SOLUTIONS INC TR          1
# 85               DOUGHERTY AIR TRUSTEE LLC TRUSTEE          1
# 86                             DESOUZA FERDINAND E          1
# 87                CLYDESDALE AVIATION HOLDINGS LLC          1
# 88                              CLARK AVIATION LLC          1
# 89                                  AERO DAVIS LLC          1
# 90                                 WARREN RANDAL W          1
# 91                                   BYLER JAMES H          1
# 92                                     REED RODNEY          1
#
# [93 rows x 2 columns]

# %% [markdown]
# Quantidade de voos por Companhia e Aeronave em cada Rota

# %%
query = '''
SHOW tables
;
'''

pd.read_sql_query(query, conn)
# Out:
#    Tables_in_usa_flights
# 0        aircraft_models
# 1         aircraft_types
# 2              aircrafts
# 3               airports
# 4                 cities
# 5              companies
# 6           delay_causes
# 7           engine_types
# 8                flights
# 9           manufacturer
# 10                routes
# 11                states

# %%
query = '''
SELECT Companies.name AS Companny,
       Aircrafts.N_Number AS Aircraft, 
       Routes.Departure_Airport_id AS Departure, 
       Routes.Arrival_Airport_id AS Arrival,
       COUNT(Aircrafts.N_Number) AS Flights
FROM Flights
INNER JOIN Aircrafts ON Aircrafts.n_number = Flights.Aircrafts_id
INNER JOIN Routes ON Flights.Route_id = Routes.id_route
INNER JOIN Companies ON Companies.id_company = Aircrafts.Companys_id
GROUP BY Companies.name, Aircrafts.N_Number, Routes.Departure_Airport_id, Routes.Arrival_Airport_id
ORDER BY Flights DESC
;
'''

pd.read_sql_query(query, conn)
# Out:
#                            Companny Aircraft Departure Arrival  Flights
# 0             HAWAIIAN AIRLINES INC   N483HA       HNL     OGG       38
# 1             HAWAIIAN AIRLINES INC   N488HA       HNL     OGG       34
# 2             HAWAIIAN AIRLINES INC   N489HA       HNL     OGG       34
# 3             AMERICAN AIRLINES INC   N945UW       LGA     BOS       33
# 4             AMERICAN AIRLINES INC   N945UW       BOS     LGA       32
# 5             HAWAIIAN AIRLINES INC   N481HA       KOA     HNL       32
# 6             HAWAIIAN AIRLINES INC   N483HA       OGG     HNL       31
# 7             HAWAIIAN AIRLINES INC   N488HA       KOA     HNL       30
# 8             HAWAIIAN AIRLINES INC   N485HA       HNL     OGG       29
# 9             HAWAIIAN AIRLINES INC   N489HA       OGG     HNL       29
# 10       BCC EQUIPMENT LEASING CORP   N495HA       HNL     OGG       29
# 11       BCC EQUIPMENT LEASING CORP   N495HA       OGG     HNL       27
# 12      WELLS FARGO BANK NA TRUSTEE   N493HA       HNL     LIH       27
# 13            HAWAIIAN AIRLINES INC   N478HA       HNL     OGG       27
# 14            HAWAIIAN AIRLINES INC   N488HA       OGG     HNL       27
# 15            HAWAIIAN AIRLINES INC   N490HA       HNL     OGG       27
# 16            HAWAIIAN AIRLINES INC   N481HA       HNL     OGG       26
# 17            SKY WEST AIRLINES INC   N907EV       PHX     SGU       26
# 18            SKY WEST AIRLINES INC   N907EV       SGU     PHX       26
# 19      WELLS FARGO BANK NA TRUSTEE   N492HA       HNL     OGG       26
# 20      WELLS FARGO BANK NA TRUSTEE   N493HA       HNL     OGG       26
# 21      WELLS FARGO BANK NA TRUSTEE   N493HA       LIH     HNL       25
# 22            HAWAIIAN AIRLINES INC   N478HA       OGG     HNL       25
# 23            HAWAIIAN AIRLINES INC   N481HA       OGG     HNL       25
# 24            HAWAIIAN AIRLINES INC   N479HA       OGG     HNL       24
# 25            HAWAIIAN AIRLINES INC   N485HA       KOA     HNL       24
# 26            HAWAIIAN AIRLINES INC   N489HA       HNL     LIH       24
# 27            HAWAIIAN AIRLINES INC   N490HA       OGG     HNL       24
# 28            HAWAIIAN AIRLINES INC   N481HA       HNL     KOA       23
# 29            HAWAIIAN AIRLINES INC   N485HA       OGG     HNL       23
# ...                             ...      ...       ...     ...      ...
# 233295  WELLS FARGO BANK NA TRUSTEE   N752SK       SBN     DFW        1
# 233296  WELLS FARGO BANK NA TRUSTEE   N752SK       CLT     FWA        1
# 233297  WELLS FARGO BANK NA TRUSTEE   N752SK       DFW     FWA        1
# 233298  WELLS FARGO BANK NA TRUSTEE   N752SK       DFW     ASE        1
# 233299  WELLS FARGO BANK NA TRUSTEE   N752SK       DFW     TYS        1
# 233300  WELLS FARGO BANK NA TRUSTEE   N752SK       TYS     CLT        1
# 233301  WELLS FARGO BANK NA TRUSTEE   N752SK       SAF     DFW        1
# 233302  WELLS FARGO BANK NA TRUSTEE   N752SK       CLT     OKC        1
# 233303  WELLS FARGO BANK NA TRUSTEE   N752SK       RDM     LAX        1
# 233304  WELLS FARGO BANK NA TRUSTEE   N752SK       EUG     PHX        1
# 233305  WELLS FARGO BANK NA TRUSTEE   N752SK       LAX     EUG        1
# 233306  WELLS FARGO BANK NA TRUSTEE   N752SK       PHX     FLG        1
# 233307  WELLS FARGO BANK NA TRUSTEE   N752SK       FLG     PHX        1
# 233308  WELLS FARGO BANK NA TRUSTEE   N752SK       PHX     FAT        1
# 233309  WELLS FARGO BANK NA TRUSTEE   N752SK       LAX     SLC        1
# 233310  WELLS FARGO BANK NA TRUSTEE   N752SK       ECP     CLT        1
# 233311  WELLS FARGO BANK NA TRUSTEE   N752SK       CHA     CLT        1
# 233312  WELLS FARGO BANK NA TRUSTEE   N752SK       CLL     DFW        1
# 233313  WELLS FARGO BANK NA TRUSTEE   N752SK       BNA     ORD        1
# 233314  WELLS FARGO BANK NA TRUSTEE   N752SK       ORD     IND        1
# 233315  WELLS FARGO BANK NA TRUSTEE   N752SK       DFW     BNA        1
# 233316  WELLS FARGO BANK NA TRUSTEE   N752SK       IND     ORD        1
# 233317  WELLS FARGO BANK NA TRUSTEE   N752SK       FSD     ORD        1
# 233318  WELLS FARGO BANK NA TRUSTEE   N752SK       CLT     SBN        1
# 233319  WELLS FARGO BANK NA TRUSTEE   N752SK       SBN     CLT        1
# 233320  WELLS FARGO BANK NA TRUSTEE   N752US       PDX     PHX        1
# 233321  WELLS FARGO BANK NA TRUSTEE   N752US       PHX     PDX        1
# 233322  WELLS FARGO BANK NA TRUSTEE   N752US       PHX     OAK        1
# 233323  WELLS FARGO BANK NA TRUSTEE   N752US       PHX     SAN        1
# 233324  WELLS FARGO BANK NA TRUSTEE   N752US       SAN     PHX        1
#
# [233325 rows x 5 columns]

# %% [markdown]
# Quantidade de voos que partiram de cada aeroporto por Companhia

# %%
query = '''
SELECT Companies.name AS Companny,
       Routes.Departure_Airport_id AS Departure, 
       COUNT(Routes.Departure_Airport_id) AS Flights
FROM Flights
INNER JOIN Aircrafts ON Aircrafts.n_number = Flights.Aircrafts_id
INNER JOIN Routes ON Flights.Route_id = Routes.id_route
INNER JOIN Companies ON Companies.id_company = Aircrafts.Companys_id
GROUP BY Companies.name, Routes.Departure_Airport_id
ORDER BY Flights DESC
;
'''

pd.read_sql_query(query, conn)
# Out:
#                                       Companny Departure  Flights
# 0                          DELTA AIR LINES INC       ATL     7058
# 1                        AMERICAN AIRLINES INC       CLT     7018
# 2                        AMERICAN AIRLINES INC       DFW     5164
# 3                          UNITED AIRLINES INC       IAH     5081
# 4                        AMERICAN AIRLINES INC       ORD     4119
# 5                       SOUTHWEST AIRLINES INC       LAS     3058
# 6                          UNITED AIRLINES INC       EWR     2989
# 7                          UNITED AIRLINES INC       ORD     2972
# 8                       SOUTHWEST AIRLINES INC       PHX     2920
# 9                          UNITED AIRLINES INC       DEN     2692
# 10                      SOUTHWEST AIRLINES INC       BWI     2560
# 11                 WELLS FARGO BANK NA TRUSTEE       DFW     2535
# 12                      SOUTHWEST AIRLINES INC       DAL     2512
# 13                      SOUTHWEST AIRLINES INC       MDW     2454
# 14                 WELLS FARGO BANK NA TRUSTEE       ATL     2430
# 15                      SOUTHWEST AIRLINES INC       DEN     2397
# 16                           MESA AIRLINES INC       DFW     2389
# 17                       SKY WEST AIRLINES INC       ORD     2296
# 18                         UNITED AIRLINES INC       SFO     2277
# 19                      SOUTHWEST AIRLINES INC       HOU     2259
# 20                         ALASKA AIRLINES INC       SEA     2074
# 21                       AMERICAN AIRLINES INC       PHL     2045
# 22                         DELTA AIR LINES INC       MSP     2004
# 23                 WELLS FARGO BANK NA TRUSTEE       PHX     1941
# 24                      SOUTHWEST AIRLINES INC       LAX     1880
# 25                 WELLS FARGO BANK NA TRUSTEE       CLT     1869
# 26                       AMERICAN AIRLINES INC       MIA     1851
# 27                       SKY WEST AIRLINES INC       DEN     1800
# 28                      SOUTHWEST AIRLINES INC       ATL     1785
# 29                      SOUTHWEST AIRLINES INC       SAN     1784
# ...                                        ...       ...      ...
# 3536                       UMB BANK NA TRUSTEE       GSO        1
# 3537                       UMB BANK NA TRUSTEE       CRP        1
# 3538                       UMB BANK NA TRUSTEE       ELP        1
# 3539                       UNITED AIRLINES INC       MDT        1
# 3540                       UNITED AIRLINES INC       LGB        1
# 3541                       UNITED AIRLINES INC       ISP        1
# 3542               WILMINGTON TRUST CO TRUSTEE       SYR        1
# 3543               WILMINGTON TRUST CO TRUSTEE       HSV        1
# 3544               WILMINGTON TRUST CO TRUSTEE       ANC        1
# 3545               WILMINGTON TRUST CO TRUSTEE       SRQ        1
# 3546                V28V OWNER STATUTORY TRUST       RDU        1
# 3547                V28V OWNER STATUTORY TRUST       ORD        1
# 3548                V28V OWNER STATUTORY TRUST       MSY        1
# 3549                V28V OWNER STATUTORY TRUST       EWR        1
# 3550                V28V OWNER STATUTORY TRUST       AUS        1
# 3551                V28V OWNER STATUTORY TRUST       BUR        1
# 3552               WELLS FARGO BANK NA TRUSTEE       STX        1
# 3553               WELLS FARGO BANK NA TRUSTEE       LCH        1
# 3554               WELLS FARGO BANK NA TRUSTEE       PPG        1
# 3555               WELLS FARGO BANK NA TRUSTEE       YAK        1
# 3556               WELLS FARGO BANK NA TRUSTEE       CDV        1
# 3557               WELLS FARGO BANK NA TRUSTEE       BET        1
# 3558               WELLS FARGO BANK NA TRUSTEE       CYS        1
# 3559               WELLS FARGO BANK NA TRUSTEE       LBF        1
# 3560               WELLS FARGO BANK NA TRUSTEE       EAU        1
# 3561               WELLS FARGO BANK NA TRUSTEE       RDD        1
# 3562  WELLS FARGO DELAWARE TRUST CO NA TRUSTEE       DTW        1
# 3563  WELLS FARGO DELAWARE TRUST CO NA TRUSTEE       JAX        1
# 3564  WELLS FARGO DELAWARE TRUST CO NA TRUSTEE       ROC        1
# 3565  WELLS FARGO DELAWARE TRUST CO NA TRUSTEE       RSW        1
#
# [3566 rows x 3 columns]

# %% [markdown]
# Quantida de voos que chegaram em cada aeroporto por Companhia

# %%
query = '''
SELECT Companies.name AS Companny,
       Routes.Arrival_Airport_id AS Arrival, 
       COUNT(Routes.Arrival_Airport_id) AS Flights
FROM Flights
INNER JOIN Aircrafts ON Aircrafts.n_number = Flights.Aircrafts_id
INNER JOIN Routes ON Flights.Route_id = Routes.id_route
INNER JOIN Companies ON Companies.id_company = Aircrafts.Companys_id
GROUP BY Companies.name, Routes.Arrival_Airport_id
ORDER BY Flights DESC
;
'''

pd.read_sql_query(query, conn)
# Out:
#                                       Companny Arrival  Flights
# 0                          DELTA AIR LINES INC     ATL     7046
# 1                        AMERICAN AIRLINES INC     CLT     6656
# 2                        AMERICAN AIRLINES INC     DFW     5124
# 3                          UNITED AIRLINES INC     IAH     5073
# 4                        AMERICAN AIRLINES INC     ORD     4213
# 5                       SOUTHWEST AIRLINES INC     LAS     3040
# 6                          UNITED AIRLINES INC     ORD     2994
# 7                          UNITED AIRLINES INC     EWR     2927
# 8                       SOUTHWEST AIRLINES INC     MDW     2888
# 9                       SOUTHWEST AIRLINES INC     DAL     2853
# 10                      SOUTHWEST AIRLINES INC     DEN     2831
# 11                         UNITED AIRLINES INC     DEN     2733
# 12                      SOUTHWEST AIRLINES INC     BWI     2692
# 13                      SOUTHWEST AIRLINES INC     PHX     2599
# 14                           MESA AIRLINES INC     DFW     2422
# 15                 WELLS FARGO BANK NA TRUSTEE     DFW     2404
# 16                 WELLS FARGO BANK NA TRUSTEE     ATL     2379
# 17                       SKY WEST AIRLINES INC     ORD     2275
# 18                         UNITED AIRLINES INC     SFO     2258
# 19                      SOUTHWEST AIRLINES INC     HOU     2213
# 20                         ALASKA AIRLINES INC     SEA     2069
# 21                       AMERICAN AIRLINES INC     PHL     2009
# 22                         DELTA AIR LINES INC     MSP     1995
# 23                 WELLS FARGO BANK NA TRUSTEE     CLT     1918
# 24                 WELLS FARGO BANK NA TRUSTEE     PHX     1805
# 25                      SOUTHWEST AIRLINES INC     LAX     1800
# 26                      SOUTHWEST AIRLINES INC     MCO     1796
# 27                       SKY WEST AIRLINES INC     DEN     1792
# 28                 WELLS FARGO BANK NA TRUSTEE     ORD     1783
# 29                      SOUTHWEST AIRLINES INC     OAK     1738
# ...                                        ...     ...      ...
# 3549                       UMB BANK NA TRUSTEE     SBA        1
# 3550                       UMB BANK NA TRUSTEE     LIH        1
# 3551                       UMB BANK NA TRUSTEE     COS        1
# 3552                       UMB BANK NA TRUSTEE     GSO        1
# 3553                       UMB BANK NA TRUSTEE     CRP        1
# 3554                       UMB BANK NA TRUSTEE     MFE        1
# 3555                       UNITED AIRLINES INC     MDT        1
# 3556               WILMINGTON TRUST CO TRUSTEE     SYR        1
# 3557               WILMINGTON TRUST CO TRUSTEE     HSV        1
# 3558               WILMINGTON TRUST CO TRUSTEE     SRQ        1
# 3559                V28V OWNER STATUTORY TRUST     JFK        1
# 3560                V28V OWNER STATUTORY TRUST     RDU        1
# 3561                V28V OWNER STATUTORY TRUST     ORD        1
# 3562                V28V OWNER STATUTORY TRUST     MSY        1
# 3563                V28V OWNER STATUTORY TRUST     EWR        1
# 3564                V28V OWNER STATUTORY TRUST     AUS        1
# 3565                V28V OWNER STATUTORY TRUST     BUR        1
# 3566               WELLS FARGO BANK NA TRUSTEE     PPG        1
# 3567               WELLS FARGO BANK NA TRUSTEE     YAK        1
# 3568               WELLS FARGO BANK NA TRUSTEE     CDV        1
# 3569               WELLS FARGO BANK NA TRUSTEE     BET        1
# 3570               WELLS FARGO BANK NA TRUSTEE     DAB        1
# 3571               WELLS FARGO BANK NA TRUSTEE     CYS        1
# 3572               WELLS FARGO BANK NA TRUSTEE     GTF        1
# 3573               WELLS FARGO BANK NA TRUSTEE     EAU        1
# 3574               WELLS FARGO BANK NA TRUSTEE     EAR        1
# 3575               WELLS FARGO BANK NA TRUSTEE     MKG        1
# 3576  WELLS FARGO DELAWARE TRUST CO NA TRUSTEE     MEM        1
# 3577  WELLS FARGO DELAWARE TRUST CO NA TRUSTEE     ROC        1
# 3578  WELLS FARGO DELAWARE TRUST CO NA TRUSTEE     MIA        1
#
# [3579 rows x 3 columns]

# %%
query = '''
SELECT Companies.name AS Companny,
       CONCAT(Routes.Departure_Airport_id,'-', Routes.Arrival_Airport_id) AS Route,
       COUNT(Aircrafts.N_Number) AS Flights
FROM Flights
INNER JOIN Aircrafts ON Aircrafts.n_number = Flights.Aircrafts_id
INNER JOIN Routes ON Flights.Route_id = Routes.id_route
INNER JOIN Companies ON Companies.id_company = Aircrafts.Companys_id
GROUP BY Companies.name, Routes.Departure_Airport_id, Routes.Arrival_Airport_id
ORDER BY Flights DESC
;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#                      Companny    Route  Flights
# 0       HAWAIIAN AIRLINES INC  HNL-OGG      321
# 1       HAWAIIAN AIRLINES INC  OGG-HNL      298
# 2      SOUTHWEST AIRLINES INC  HOU-DAL      285
# 3      SOUTHWEST AIRLINES INC  DAL-HOU      253
# 4       HAWAIIAN AIRLINES INC  KOA-HNL      235
# 5       AMERICAN AIRLINES INC  CLT-DFW      231
# 6      SOUTHWEST AIRLINES INC  SAN-SJC      225
# 7      SOUTHWEST AIRLINES INC  SJC-SAN      217
# 8         DELTA AIR LINES INC  MCO-ATL      216
# 9       AMERICAN AIRLINES INC  DFW-CLT      213
# 10      AMERICAN AIRLINES INC  LGA-BOS      213
# 11      AMERICAN AIRLINES INC  CLT-GSP      212
# 12        DELTA AIR LINES INC  ATL-MCO      210
# 13      HAWAIIAN AIRLINES INC  HNL-LIH      209
# 14     SOUTHWEST AIRLINES INC  SMF-SAN      208
# 15      AMERICAN AIRLINES INC  BOS-LGA      208
# 16     SOUTHWEST AIRLINES INC  SAN-SMF      202
# 17     SOUTHWEST AIRLINES INC  LAX-OAK      201
# 18        UNITED AIRLINES INC  IAH-DEN      201
# 19        ALASKA AIRLINES INC  SEA-ANC      200
# 20      AMERICAN AIRLINES INC  BOS-PHL      199
# 21     SOUTHWEST AIRLINES INC  OAK-LAX      199
# 22        UNITED AIRLINES INC  SFO-EWR      198
# 23      AMERICAN AIRLINES INC  GSO-CLT      197
# 24        UNITED AIRLINES INC  EWR-SFO      195
# 25     SOUTHWEST AIRLINES INC  PHX-LAS      195
# 26      AMERICAN AIRLINES INC  SAV-CLT      194
# 27      AMERICAN AIRLINES INC  CLT-MYR      194
# 28      HAWAIIAN AIRLINES INC  LIH-HNL      193
# 29      AMERICAN AIRLINES INC  PHL-CLT      192
# ...                       ...      ...      ...
# 21936   SKY WEST AIRLINES INC  IAD-SCE        1
# 21937   SKY WEST AIRLINES INC  GSP-IAD        1
# 21938   SKY WEST AIRLINES INC  IAD-GSP        1
# 21939   SKY WEST AIRLINES INC  HSV-ORD        1
# 21940   SKY WEST AIRLINES INC  IAD-HSV        1
# 21941   SKY WEST AIRLINES INC  ALB-IAD        1
# 21942   SKY WEST AIRLINES INC  IAD-ALB        1
# 21943   SKY WEST AIRLINES INC  DTW-MSY        1
# 21944   SKY WEST AIRLINES INC  MSY-DTW        1
# 21945   SKY WEST AIRLINES INC  FAR-ATL        1
# 21946   SKY WEST AIRLINES INC  ATL-FAR        1
# 21947   SKY WEST AIRLINES INC  CHA-IAD        1
# 21948   SKY WEST AIRLINES INC  ORD-ROC        1
# 21949   SKY WEST AIRLINES INC  ORD-ABE        1
# 21950   SKY WEST AIRLINES INC  RDU-CVG        1
# 21951   SKY WEST AIRLINES INC  DTW-EVV        1
# 21952   SKY WEST AIRLINES INC  ATL-ILM        1
# 21953   SKY WEST AIRLINES INC  ILM-ATL        1
# 21954   SKY WEST AIRLINES INC  LGA-BGR        1
# 21955   SKY WEST AIRLINES INC  ROC-LGA        1
# 21956   SKY WEST AIRLINES INC  GTR-ATL        1
# 21957   SKY WEST AIRLINES INC  SYR-DTW        1
# 21958   SKY WEST AIRLINES INC  MHT-LGA        1
# 21959   SKY WEST AIRLINES INC  LGA-MHT        1
# 21960   SKY WEST AIRLINES INC  AEX-ATL        1
# 21961   SKY WEST AIRLINES INC  IAD-JFK        1
# 21962   SKY WEST AIRLINES INC  JFK-BWI        1
# 21963   SKY WEST AIRLINES INC  JFK-IAD        1
# 21964   SKY WEST AIRLINES INC  IAH-PNS        1
# 21965   SKY WEST AIRLINES INC  PNS-IAH        1
#
# [21966 rows x 3 columns]

# %%
G = nx.DiGraph()

j = 0

for ind in df.index:
    G.add_node(df.loc[ind, 'Companny'], color = 'blue')
    G.add_node(df.loc[ind, 'Route'], color = 'green')
    G.add_edge(df.loc[ind, 'Companny'], df.loc[ind, 'Route'],
                   color='violet',
                   relation='has route')

# %%
fig, ax = plt.subplots(figsize=(20,20))
pos = nx.spring_layout(G, scale=1)

nx.draw_networkx(G, pos = pos, ax = ax)

plt.savefig("./Graph.png", format="png", dpi=100)
plt.show()
# Out:
# C:\Users\igorm\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\igorm\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
G = nx.DiGraph()

j = 0

for ind in df.index:
    if df.loc[ind, 'Flights'] >= 180:
        G.add_node(df.loc[ind, 'Companny'], color = 'blue')
        G.add_node(df.loc[ind, 'Route'], color = 'green')
        G.add_edge(df.loc[ind, 'Companny'], df.loc[ind, 'Route'],
                       color='red')
        

fig, ax = plt.subplots(figsize=(20,20))
pos = nx.spring_layout(G, scale=1)

nx.draw_networkx(G,
                 pos = pos,
                 ax = ax,
                 node_color = [nx.get_node_attributes(G,'color')[g] for g in G.nodes()],
                 edge_color = [nx.get_edge_attributes(G,'color')[g] for g in G.edges()],)
# Out:
# C:\Users\igorm\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \

# %%
where = "WHERE Companies.name IN ('DELTA AIR LINES INC', 'SOUTHWEST AIRLINES INC', 'UNITED AIRLINES INC', 'AMERICAN AIRLINES INC', 'WELLS FARGO BANK NA TRUSTEE')"

query = '''
SELECT Companies.name AS Companny,
       CONCAT(Routes.Departure_Airport_id,'-', Routes.Arrival_Airport_id) AS Route,
       COUNT(Aircrafts.N_Number) AS Flights
FROM Flights
INNER JOIN Aircrafts ON Aircrafts.n_number = Flights.Aircrafts_id
INNER JOIN Routes ON Flights.Route_id = Routes.id_route
INNER JOIN Companies ON Companies.id_company = Aircrafts.Companys_id
{0}
GROUP BY Companies.name, Routes.Departure_Airport_id, Routes.Arrival_Airport_id
ORDER BY Flights DESC
;
'''.format(where)

df = pd.read_sql_query(query, conn)
df
# Out:
#                          Companny    Route  Flights
# 0          SOUTHWEST AIRLINES INC  HOU-DAL      285
# 1          SOUTHWEST AIRLINES INC  DAL-HOU      253
# 2           AMERICAN AIRLINES INC  CLT-DFW      231
# 3          SOUTHWEST AIRLINES INC  SAN-SJC      225
# 4          SOUTHWEST AIRLINES INC  SJC-SAN      217
# 5             DELTA AIR LINES INC  MCO-ATL      216
# 6           AMERICAN AIRLINES INC  DFW-CLT      213
# 7           AMERICAN AIRLINES INC  LGA-BOS      213
# 8           AMERICAN AIRLINES INC  CLT-GSP      212
# 9             DELTA AIR LINES INC  ATL-MCO      210
# 10          AMERICAN AIRLINES INC  BOS-LGA      208
# 11         SOUTHWEST AIRLINES INC  SMF-SAN      208
# 12         SOUTHWEST AIRLINES INC  SAN-SMF      202
# 13         SOUTHWEST AIRLINES INC  LAX-OAK      201
# 14            UNITED AIRLINES INC  IAH-DEN      201
# 15          AMERICAN AIRLINES INC  BOS-PHL      199
# 16         SOUTHWEST AIRLINES INC  OAK-LAX      199
# 17            UNITED AIRLINES INC  SFO-EWR      198
# 18          AMERICAN AIRLINES INC  GSO-CLT      197
# 19         SOUTHWEST AIRLINES INC  PHX-LAS      195
# 20            UNITED AIRLINES INC  EWR-SFO      195
# 21          AMERICAN AIRLINES INC  SAV-CLT      194
# 22          AMERICAN AIRLINES INC  CLT-MYR      194
# 23          AMERICAN AIRLINES INC  PHL-CLT      192
# 24    WELLS FARGO BANK NA TRUSTEE  BOS-DCA      192
# 25            UNITED AIRLINES INC  DEN-IAH      191
# 26         SOUTHWEST AIRLINES INC  PHX-DEN      190
# 27    WELLS FARGO BANK NA TRUSTEE  DCA-BOS      188
# 28         SOUTHWEST AIRLINES INC  SNA-SJC      181
# 29         SOUTHWEST AIRLINES INC  LAX-SJC      177
# ...                           ...      ...      ...
# 8726  WELLS FARGO BANK NA TRUSTEE  LWB-ORD        1
# 8727  WELLS FARGO BANK NA TRUSTEE  DEN-EAR        1
# 8728  WELLS FARGO BANK NA TRUSTEE  DEN-RAP        1
# 8729  WELLS FARGO BANK NA TRUSTEE  RAP-DEN        1
# 8730  WELLS FARGO BANK NA TRUSTEE  DEN-MRY        1
# 8731  WELLS FARGO BANK NA TRUSTEE  SHD-IAD        1
# 8732  WELLS FARGO BANK NA TRUSTEE  ORD-XNA        1
# 8733  WELLS FARGO BANK NA TRUSTEE  ORD-SHD        1
# 8734  WELLS FARGO BANK NA TRUSTEE  RDD-SFO        1
# 8735  WELLS FARGO BANK NA TRUSTEE  BFL-SFO        1
# 8736  WELLS FARGO BANK NA TRUSTEE  DTW-SRQ        1
# 8737  WELLS FARGO BANK NA TRUSTEE  SRQ-DTW        1
# 8738  WELLS FARGO BANK NA TRUSTEE  ORD-LIT        1
# 8739  WELLS FARGO BANK NA TRUSTEE  IAH-XNA        1
# 8740  WELLS FARGO BANK NA TRUSTEE  DEN-CPR        1
# 8741  WELLS FARGO BANK NA TRUSTEE  IAH-LIT        1
# 8742  WELLS FARGO BANK NA TRUSTEE  ORD-TUL        1
# 8743  WELLS FARGO BANK NA TRUSTEE  BZN-SFO        1
# 8744  WELLS FARGO BANK NA TRUSTEE  GEG-SFO        1
# 8745  WELLS FARGO BANK NA TRUSTEE  SFO-BZN        1
# 8746  WELLS FARGO BANK NA TRUSTEE  PRC-DEN        1
# 8747  WELLS FARGO BANK NA TRUSTEE  DEN-SGF        1
# 8748  WELLS FARGO BANK NA TRUSTEE  SGF-DEN        1
# 8749  WELLS FARGO BANK NA TRUSTEE  SFO-STS        1
# 8750  WELLS FARGO BANK NA TRUSTEE  STS-SFO        1
# 8751  WELLS FARGO BANK NA TRUSTEE  DVL-DEN        1
# 8752  WELLS FARGO BANK NA TRUSTEE  ORD-MKG        1
# 8753  WELLS FARGO BANK NA TRUSTEE  LAX-GEG        1
# 8754  WELLS FARGO BANK NA TRUSTEE  GEG-LAX        1
# 8755  WELLS FARGO BANK NA TRUSTEE  ATL-SYR        1
#
# [8756 rows x 3 columns]

# %%
G = nx.DiGraph()

j = 0

for ind in df.index:
    if df.loc[ind, 'Flights'] >= 100:
        G.add_node(df.loc[ind, 'Companny'], color = 'blue')
        G.add_node(df.loc[ind, 'Route'], color = 'green')
        G.add_edge(df.loc[ind, 'Companny'], df.loc[ind, 'Route'],
                   color='red')
        

fig, ax = plt.subplots(figsize=(20,20))
pos = nx.spring_layout(G, scale=1)

nx.draw_networkx(G,
                 pos = pos,
                 ax = ax,
                 node_color = [nx.get_node_attributes(G,'color')[g] for g in G.nodes()],
                 edge_color = [nx.get_edge_attributes(G,'color')[g] for g in G.edges()],)

plt.savefig("./5_Companies.png", format="png", dpi=100)
plt.show()
